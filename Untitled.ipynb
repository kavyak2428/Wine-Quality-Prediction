# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load dataset
file_path = "WineQT.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# %%
# Drop unnecessary columns
df.drop(columns=['Id'], inplace=True)

# %%
# Function to remove outliers using IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
# Removing outliers from key columns
columns_to_clean = ["residual sugar", "chlorides", "total sulfur dioxide", "sulphates"]
for col in columns_to_clean:
    df = remove_outliers(df, col)

# %%
# Visualizing Wine Quality Distribution
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="quality", hue="quality", palette="coolwarm", legend=False)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
plt.title("Wine Quality Distribution")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()

# %%
# Splitting features and target
X = df.drop(columns=["quality"])
y = df["quality"]

# %%
# Scaling features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Initialize models
rf_model = RandomForestClassifier(random_state=42)
sgd_model = SGDClassifier(random_state=42)
svc_model = SVC(random_state=42)

# %%
# Train models
rf_model.fit(X_train, y_train)
sgd_model.fit(X_train, y_train)
svc_model.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
# Predictions
rf_pred = rf_model.predict(X_test)
sgd_pred = sgd_model.predict(X_test)
svc_pred = svc_model.predict(X_test)
rf_acc = accuracy_score(y_test, rf_pred)
sgd_acc = accuracy_score(y_test, sgd_pred)
svc_acc = accuracy_score(y_test, svc_pred)

# %%
# Evaluation
print(classification_report(y_test, rf_pred, zero_division=1))
print(classification_report(y_test, sgd_pred, zero_division=1))
print(classification_report(y_test, svc_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      0.00      0.00         2
#            4       1.00      0.00      0.00         3
#            5       0.67      0.74      0.70        72
#            6       0.68      0.68      0.68        80
#            7       0.72      0.65      0.68        20
#            8       0.33      0.33      0.33         3
#
#     accuracy                           0.67       180
#    macro avg       0.73      0.40      0.40       180
# weighted avg       0.68      0.67      0.66       180
#
#               precision    recall  f1-score   support
#
#            3       1.00      0.00      0.00         2
#            4       1.00      0.00      0.00         3
#            5       0.69      0.75      0.72        72
#            6       0.81      0.28      0.41        80
#            7       0.25      0.95      0.40        20
#            8       1.00      0.00      0.00         3
#
# ...

# %%
# Calculate accuracy before printing
rf_acc = accuracy_score(y_test, rf_pred)
sgd_acc = accuracy_score(y_test, sgd_pred)
svc_acc = accuracy_score(y_test, svc_pred)

# %%
# Display results
print(f"Random Forest Accuracy: {rf_acc:.2f}")
print(classification_report(y_test, rf_pred, zero_division=0))
# Out:
# Random Forest Accuracy: 0.67
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         3
#            5       0.67      0.74      0.70        72
#            6       0.68      0.68      0.68        80
#            7       0.72      0.65      0.68        20
#            8       0.33      0.33      0.33         3
#
#     accuracy                           0.67       180
#    macro avg       0.40      0.40      0.40       180
# weighted avg       0.65      0.67      0.66       180

# %%
print(f"SGD Accuracy: {sgd_acc:.2f}")
print(classification_report(y_test, sgd_pred, zero_division=0))
# Out:
# SGD Accuracy: 0.53
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         3
#            5       0.69      0.75      0.72        72
#            6       0.81      0.28      0.41        80
#            7       0.25      0.95      0.40        20
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.53       180
#    macro avg       0.29      0.33      0.26       180
# weighted avg       0.67      0.53      0.52       180

# %%
print(f"SVC Accuracy: {svc_acc:.2f}")
print(classification_report(y_test, svc_pred, zero_division=0))
# Out:
# SVC Accuracy: 0.67
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         3
#            5       0.66      0.79      0.72        72
#            6       0.66      0.69      0.67        80
#            7       0.73      0.40      0.52        20
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.67       180
#    macro avg       0.34      0.31      0.32       180
# weighted avg       0.64      0.67      0.65       180

# %% [raw]
# #Results:
#
# Best Model: Random Forest (~67% accuracy)
# SGD struggles with class imbalance
# SVC performs close to Random Forest but slightly weaker
